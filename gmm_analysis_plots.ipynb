# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa as lb

# %%
# All numbers are taken from manual observations

n_iterations = [5, 10, 20, 50, 100, 200, 500]
n_it_acc = [71.42857142857143, 73.57142857142857, 77.85714285714286, 75.0, 78.57142857142857, 79.28571428571429, 79.28571428571429]

n_mfcc = [5, 7, 9, 11, 13, 15, 17]
n_mfcc_acc = [38.57142857142857, 52.142857142857146, 63.57142857142857, 71.42857142857143, 77.85714285714286, 82.14285714285714, 81.42857142857143]

n_mixtures = [4, 8, 16, 32, 64, 128, 256]
n_mix_acc = [57.142857142857146, 67.85714285714286, 79.28571428571429, 78.57142857142857, 78.57142857142857, 80.71428571428571, 80.0]

feat_red_method = ["None", "PCA", "Truncated SVD"]
feat_acc = [90.71428571428571, 57.142857142857146, 71.42857142857143]

# %% [markdown]
# # Model Accuracy vs Number of Iterations

# %%
plt.figure(figsize=(16, 10))
plt.xticks(n_iterations)
plt.plot(n_iterations, n_it_acc, 'o-')
plt.xlabel("Number of Iterations")
plt.xticks(n_iterations)
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of Iterations")
plt.savefig("acc_vs_it.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# # Model Accuracy vs Number of MFCCs

# %%
plt.figure(figsize=(16, 10))
plt.xticks(n_mfcc)
plt.plot(n_mfcc, n_mfcc_acc, 'o-')
plt.xlabel("Number of MFCCs")
plt.xticks(n_mfcc)
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of MFCCs")
plt.savefig("acc_vs_mfcc.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# # Model Accuracy vs Number of Mixtures

# %%
plt.figure(figsize=(16, 10))
plt.xticks(n_mixtures)
plt.plot(n_mixtures, n_mix_acc, 'o-')
plt.xlabel("Number of Mixtures")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Number of Mixtures")
plt.savefig("acc_vs_mix.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# # Model Accuracy vs Feature Reduction Method

# %%
plt.figure(figsize=(16, 10))
plt.bar(feat_red_method, feat_acc, align='center', width=0.5)
plt.xlabel("Feature Reduction Method")
plt.ylabel("Accuracy")
plt.ylim([0, 100])
plt.title("Accuracy vs Feature Reduction Method")
plt.savefig("acc_vs_feat_red.png", bbox_inches='tight')
